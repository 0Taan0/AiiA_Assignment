# %%
import pandas as pd
import os

# %%
# List all CSV files in the current working directory
csv_files = [file for file in os.listdir() if file.endswith('.csv')]

# Create a list to store DataFrames
dataframes = []

# Read each CSV file and add it to the DataFrame list
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    dataframes.append(df)

# Combine all DataFrames into a single DataFrame
combined_df = pd.concat(dataframes, ignore_index=True)

# Save the combined DataFrame to a new CSV file
combined_df.to_csv("combined_evaluation.csv", index=False)

print("CSV files combined successfully into 'combined_evaluation.csv'")
# Out:
# CSV files combined successfully into 'combined_evaluation.csv'

# %%
df = pd.read_csv('combined_evaluation.csv')
df
# Out:
#                                Model  Prediction Count - Class 1  \
# 0  distilbert-base-uncased-10-epochs                         565
# 1   distilbert-base-uncased-5-epochs                         534
# 2       distilroberta-base-10-epochs                         575
# 3        distilroberta-base-5-epochs                         467
# 4  distilroberta_financial-10-epochs                         598
# 5   distilroberta_financial-5-epochs                         558
# 6                  Finbert-10-epochs                         630
# 7                   Finbert-5-epochs                         553
# 8        Finbert_sentiment-10-epochs                         523
# 9         Finbert_Sentiment-5-epochs                         585
#
#    Prediction Count - Class 0  Class 0 - precision  Class 0 - recall  \
# 0                         135             0.659259          0.415888
# 1                         166             0.590361          0.457944
# ...
